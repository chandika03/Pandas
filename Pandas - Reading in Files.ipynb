# %%
import pandas as pd

# %%
df = pd.read_csv("D:\data_analysis\File2\panda.csv")
df
# Out:
#      iso_code continent        location
# 0         AFG      Asia     Afghanistan
# 1    OWID_AFR       NaN          Africa
# 2         ALB    Europe         Albania
# 3         DZA    Africa         Algeria
# 4         AND    Europe         Andorra
# ..        ...       ...             ...
# 243       ESH    Africa  Western Sahara
# 244  OWID_WRL       NaN           World
# 245       YEM      Asia           Yemen
# 246       ZMB    Africa          Zambia
# 247       ZWE    Africa        Zimbabwe
#
# [248 rows x 3 columns]

# %%
df = pd.read_csv("D:\data_analysis\File2\panda.csv")
df
# Out:
#      iso_code      continent                          location
# 0         AFG           Asia                       Afghanistan
# 1    OWID_AFR            NaN                            Africa
# 2         ALB         Europe                           Albania
# 3         DZA         Africa                           Algeria
# 4         AND         Europe                           Andorra
# 5         AGO         Africa                            Angola
# 6         AIA  North America                          Anguilla
# 7         ATG  North America               Antigua and Barbuda
# 8         ARG  South America                         Argentina
# 9         ARM           Asia                           Armenia
# 10        ABW  North America                             Aruba
# 11   OWID_ASI            NaN                              Asia
# 12        AUS        Oceania                         Australia
# 13        AUT         Europe                           Austria
# ...

# %%
pd.set_option("display.max.rows", 250)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   iso_code   248 non-null    object
#  1   continent  235 non-null    object
#  2   location   248 non-null    object
# dtypes: object(3)
# memory usage: 5.9+ KB

# %%
df.shape
# Out:
# (248, 3)

# %%
df["location"]
# Out:
# 0                           Afghanistan
# 1                                Africa
# 2                               Albania
# 3                               Algeria
# 4                               Andorra
# 5                                Angola
# 6                              Anguilla
# 7                   Antigua and Barbuda
# 8                             Argentina
# 9                               Armenia
# 10                                Aruba
# 11                                 Asia
# 12                            Australia
# 13                              Austria
# 14                           Azerbaijan
# 15                              Bahamas
# 16                              Bahrain
# 17                           Bangladesh
# 18                             Barbados
# 19                              Belarus
# 20                              Belgium
# 21                               Belize
# 22                                Benin
# ...

# %%
df.loc['Nepal']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.loc['Nepal']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
#    1292     # GH#5567 this will fail if the label is not present in the axis.
# ...

# %%
df.iloc[156]
# Out:
# iso_code         NGA
# continent     Africa
# location     Nigeria
# Name: 156, dtype: object
