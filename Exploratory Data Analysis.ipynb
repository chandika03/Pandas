# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\dell\Downloads\world_population (1).csv")

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
pd.set_option("display.float_format", lambda x: "%.2f" %x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
df.describe()
# Out:
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           230.00           233.00           230.00
# mean  117.50      34632250.88      33600710.95      32066004.16
# std    67.69     137889172.44     135873196.61     131507146.34
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        406471.00        394295.00
# 50%   117.50       5762857.00       5456681.00       5244415.00
# 75%   175.75      22653719.00      21522626.00      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           227.00           227.00           229.00           229.00
# mean       30270164.48      26840495.26      19330463.93      16282884.78
# std       126074183.54     113352454.57      81309624.96      69345465.54
# min             596.00           651.00           700.00           733.00
# ...

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     231
# Density (per km²)              230
# Growth Rate                    178
# World Population Percentage     70
# dtype: int64

# %%
df.sort_values(by="2022 Population").head()
# Out:
#      Rank CCA3           Country       Capital      Continent  \
# 226   234  VAT      Vatican City  Vatican City         Europe
# 209   233  TKL           Tokelau      Nukunonu        Oceania
# 150   232  NIU              Niue         Alofi        Oceania
# 64    231  FLK  Falkland Islands       Stanley  South America
# 137   230  MSR        Montserrat        Brades  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 226           510.00           520.00           564.00           596.00
# 209          1871.00          1827.00          1454.00          1367.00
# 150          1934.00          1942.00          1847.00          1812.00
# 64           3780.00          3747.00          3408.00          3187.00
# 137          4390.00          4500.00          5059.00          4938.00
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 226           651.00           700.00           733.00           752.00
# ...

# %%
df.sort_values(by="2022 Population", ascending = False).head(10)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41     1425887337.00    1424929781.00    1393715448.00    1348191368.00
# 92     1417173173.00    1396387127.00    1322866505.00    1240613620.00
# ...

# %%
#df.corr()

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
correlation = numeric_df.corr()
print(correlation)
# Out:
#                              Rank  2022 Population  2020 Population  \
# Rank                         1.00            -0.36            -0.36
# 2022 Population             -0.36             1.00             1.00
# 2020 Population             -0.36             1.00             1.00
# 2015 Population             -0.35             1.00             1.00
# 2010 Population             -0.35             1.00             1.00
# 2000 Population             -0.34             0.99             1.00
# 1990 Population             -0.33             0.99             0.99
# 1980 Population             -0.33             0.99             0.99
# 1970 Population             -0.34             0.97             0.98
# Area (km²)                  -0.38             0.45             0.45
# Density (per km²)            0.13            -0.03            -0.03
# Growth Rate                 -0.22            -0.02            -0.03
# World Population Percentage -0.36             1.00             1.00
#
# ...

# %%
sns.heatmap(numeric_df.corr(), annot = True)
plt.rcParams['figure.figsize'] = (20,7)

plt.show()

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# ...

# %%
numeric_df
# Out:
#      Rank  2022 Population  2020 Population  2015 Population  2010 Population  \
# 0      36      41128771.00      38972230.00      33753499.00      28189672.00
# 1     138       2842321.00       2866849.00       2882481.00       2913399.00
# 2      34      44903225.00      43451666.00      39543154.00      35856344.00
# 3     213         44273.00         46189.00         51368.00         54849.00
# 4     203         79824.00         77700.00         71746.00         71519.00
# ..    ...              ...              ...              ...              ...
# 229   226         11572.00         11655.00         12182.00         13142.00
# 230   172        575986.00        556048.00        491824.00        413296.00
# 231    46      33696614.00      32284046.00      28516545.00      24743946.00
# 232    63      20017675.00      18927715.00              NaN      13792086.00
# 233    74      16320537.00      15669666.00      14154937.00      12839771.00
#
# ...

# %%
print(df.dtypes)
# Out:
# Rank                             int64
# CCA3                            object
# Country                         object
# Capital                         object
# Continent                       object
# 2022 Population                float64
# 2020 Population                float64
# 2015 Population                float64
# 2010 Population                float64
# 2000 Population                float64
# 1990 Population                float64
# 1980 Population                float64
# 1970 Population                float64
# Area (km²)                     float64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %%
for col in df.columns:
    if col != 'Continent':
        df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
grouped_means = df.groupby('Continent').mean(numeric_only=True)
print(grouped_means)
# Out:
#                 Rank  CCA3  Country  Capital  2022 Population  \
# Continent
# Africa         92.16   NaN      NaN      NaN      25455879.68
# Asia           77.56   NaN      NaN      NaN      96327387.31
# Europe        124.50   NaN      NaN      NaN      15055371.82
# North America 160.93   NaN      NaN      NaN      15007403.40
# Oceania       188.52   NaN      NaN      NaN       2046386.32
# South America  97.57   NaN      NaN      NaN      31201186.29
#
#                2020 Population  2015 Population  2010 Population  \
# Continent
# Africa             23871435.26      21419703.57      18898197.31
# Asia               94955134.37      89165003.64      89087770.00
# Europe             14915843.92      15027454.12      14712278.68
# North America      14855914.82      14259596.25      13568016.28
# Oceania             1910148.96       1756664.48       1613163.65
# South America      30823574.50      29509599.71      26789395.54
#
# ...

# %%
df[df['Continent'].str.contains('Oceania')]
# Out:
#      Rank  CCA3  Country  Capital Continent  2022 Population  2020 Population  \
# 3     213   NaN      NaN      NaN   Oceania         44273.00         46189.00
# 11     55   NaN      NaN      NaN   Oceania      26177413.00      25670051.00
# 44    223   NaN      NaN      NaN   Oceania         17011.00         17029.00
# 66    162   NaN      NaN      NaN   Oceania        929766.00        920422.00
# 70    183   NaN      NaN      NaN   Oceania        306279.00        301920.00
# 81    191   NaN      NaN      NaN   Oceania        171774.00        169231.00
# 107   192   NaN      NaN      NaN   Oceania        131232.00        126463.00
# 126   215   NaN      NaN      NaN   Oceania         41569.00         43413.00
# 132   194   NaN      NaN      NaN   Oceania        114164.00        112106.00
# 142   225   NaN      NaN      NaN   Oceania         12668.00         12315.00
# 145   185   NaN      NaN      NaN   Oceania        289950.00        286403.00
# ...

# %%
df.groupby('Continent').mean().sort_values(by="2022 Population", ascending = False)
# Out:
#                 Rank  CCA3  Country  Capital  2022 Population  \
# Continent
# Asia           77.56   NaN      NaN      NaN      96327387.31
# South America  97.57   NaN      NaN      NaN      31201186.29
# Africa         92.16   NaN      NaN      NaN      25455879.68
# Europe        124.50   NaN      NaN      NaN      15055371.82
# North America 160.93   NaN      NaN      NaN      15007403.40
# Oceania       188.52   NaN      NaN      NaN       2046386.32
#
#                2020 Population  2015 Population  2010 Population  \
# Continent
# Asia               94955134.37      89165003.64      89087770.00
# South America      30823574.50      29509599.71      26789395.54
# Africa             23871435.26      21419703.57      18898197.31
# Europe             14915843.92      15027454.12      14712278.68
# North America      14855914.82      14259596.25      13568016.28
# Oceania             1910148.96       1756664.48       1613163.65
#
# ...

# %%
df2 = df.groupby('Continent')[['1970 Population',
       '1980 Population', '1990 Population', '2000 Population',
       '2010 Population', '2015 Population', '2020 Population',
       '2022 Population']].mean().sort_values(by="2022 Population", ascending = False)

# %% [markdown]
# df2.plot()

# %%
df2
# Out:
#                1970 Population  1980 Population  1990 Population  \
# Continent
# Asia               43839877.83      40278333.33      48639995.33
# South America      13781939.71      17270643.29      21224743.93
# Africa              6567175.27       8586031.98      11376964.52
# Europe             13118479.82      14200004.52      14785203.94
# North America       7885865.15       9207334.03      10531660.62
# Oceania              846968.26        996532.17       1162774.87
#
#                2000 Population  2010 Population  2015 Population  \
# Continent
# Asia               80580835.11      89087770.00      89165003.64
# South America      25015888.69      26789395.54      29509599.71
# Africa             14598365.95      18898197.31      21419703.57
# Europe             14817685.71      14712278.68      15027454.12
# North America      12151739.60      13568016.28      14259596.25
# Oceania             1357512.09       1613163.65       1756664.48
#
# ...

# %%
df3 = df2.transpose()

# %%
df3.plot()
# Out:
# <Axes: >

# %%
df.boxplot(figsize=(20,10))
# Out:
# <Axes: >

# %%
df
# Out:
#      Rank  CCA3  Country  Capital Continent  2022 Population  2020 Population  \
# 0      36   NaN      NaN      NaN      Asia      41128771.00      38972230.00
# 1     138   NaN      NaN      NaN    Europe       2842321.00       2866849.00
# 2      34   NaN      NaN      NaN    Africa      44903225.00      43451666.00
# 3     213   NaN      NaN      NaN   Oceania         44273.00         46189.00
# 4     203   NaN      NaN      NaN    Europe         79824.00         77700.00
# ..    ...   ...      ...      ...       ...              ...              ...
# 229   226   NaN      NaN      NaN   Oceania         11572.00         11655.00
# 230   172   NaN      NaN      NaN    Africa        575986.00        556048.00
# 231    46   NaN      NaN      NaN      Asia      33696614.00      32284046.00
# 232    63   NaN      NaN      NaN    Africa      20017675.00      18927715.00
# 233    74   NaN      NaN      NaN    Africa      16320537.00      15669666.00
#
# ...

# %%
df.dtypes
# Out:
# Rank                             int64
# CCA3                           float64
# Country                        float64
# Capital                        float64
# Continent                       object
# 2022 Population                float64
# 2020 Population                float64
# 2015 Population                float64
# 2010 Population                float64
# 2000 Population                float64
# 1990 Population                float64
# 1980 Population                float64
# 1970 Population                float64
# Area (km²)                     float64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %%
df['CCA3'] = df["CCA3"].astype(object)

# %%
df.dtypes
# Out:
# Rank                             int64
# CCA3                            object
# Country                        float64
# Capital                        float64
# Continent                       object
# 2022 Population                float64
# 2020 Population                float64
# 2015 Population                float64
# 2010 Population                float64
# 2000 Population                float64
# 1990 Population                float64
# 1980 Population                float64
# 1970 Population                float64
# Area (km²)                     float64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %%
df['Country'] = df["Country"].astype(object)
df['Capital'] = df["Capital"].astype(object)

# %%
df.dtypes
# Out:
# Rank                             int64
# CCA3                            object
# Country                         object
# Capital                         object
# Continent                       object
# 2022 Population                float64
# 2020 Population                float64
# 2015 Population                float64
# 2010 Population                float64
# 2000 Population                float64
# 1990 Population                float64
# 1980 Population                float64
# 1970 Population                float64
# Area (km²)                     float64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %%
df
# Out:
#      Rank CCA3 Country Capital Continent  2022 Population  2020 Population  \
# 0      36  NaN     NaN     NaN      Asia      41128771.00      38972230.00
# 1     138  NaN     NaN     NaN    Europe       2842321.00       2866849.00
# 2      34  NaN     NaN     NaN    Africa      44903225.00      43451666.00
# 3     213  NaN     NaN     NaN   Oceania         44273.00         46189.00
# 4     203  NaN     NaN     NaN    Europe         79824.00         77700.00
# ..    ...  ...     ...     ...       ...              ...              ...
# 229   226  NaN     NaN     NaN   Oceania         11572.00         11655.00
# 230   172  NaN     NaN     NaN    Africa        575986.00        556048.00
# 231    46  NaN     NaN     NaN      Asia      33696614.00      32284046.00
# 232    63  NaN     NaN     NaN    Africa      20017675.00      18927715.00
# 233    74  NaN     NaN     NaN    Africa      16320537.00      15669666.00
#
# ...

# %%
df.select_dtypes(include='number')
# Out:
#      Rank  2022 Population  2020 Population  2015 Population  2010 Population  \
# 0      36      41128771.00      38972230.00      33753499.00      28189672.00
# 1     138       2842321.00       2866849.00       2882481.00       2913399.00
# 2      34      44903225.00      43451666.00      39543154.00      35856344.00
# 3     213         44273.00         46189.00         51368.00         54849.00
# 4     203         79824.00         77700.00         71746.00         71519.00
# ..    ...              ...              ...              ...              ...
# 229   226         11572.00         11655.00         12182.00         13142.00
# 230   172        575986.00        556048.00        491824.00        413296.00
# 231    46      33696614.00      32284046.00      28516545.00      24743946.00
# 232    63      20017675.00      18927715.00              NaN      13792086.00
# 233    74      16320537.00      15669666.00      14154937.00      12839771.00
#
# ...
